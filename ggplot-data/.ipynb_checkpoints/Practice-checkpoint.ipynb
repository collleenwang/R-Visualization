# %%
library(readr)

ages <- read_csv("ages.csv")

head(ages)
# Out:
# Parsed with column specification:
# cols(
#   Movie = col_character(),
#   Genre = col_character(),
#   actor = col_character(),
#   actor_age = col_integer(),
#   actress = col_character(),
#   actress_age = col_integer(),
#   budget = col_double()
# )
#   Movie               Genre actor             actor_age actress
# 1 Mo' Better Blues    drama Denzel Washington 35        Joie Lee
# 2 Malcolm X           drama Denzel Washington 37        Angela Bassett
# 3 The Preacher's Wife drama Denzel Washington 41        Whitney Houston
# 4 He Got Game         drama Denzel Washington 43        Milla Jovovich
# 5 Remember the Titans drama Denzel Washington 45        Micole Ari Parker
# 6 Training Day        drama Denzel Washington 46        Eva Mendes
#   actress_age budget
# 1 28          10
# 2 34          34
# 3 33          40
# 4 22          25
# 5 29          30
# 6 27          45

# %%
library(ggplot2)

ggplot(data=ages) +
   geom_point(mapping=aes(x=actor_age, y=actress_age)) + 
   expand_limits(x = 0, y = 0 ) +
   geom_abline(intercept=0, col="light gray")
# Out:
# plot without title

# %%
ggplot(ages,
    aes(x=actor)) +
    geom_bar()
# Out:
# plot without title

# %%
ggplot(data=ages,
  aes(x=actor, fill=Genre)) +
  geom_bar()
# Out:
# plot without title

# %%
ggplot(data=ages,
  aes(x=actor, color=Genre)) +
  geom_bar()
# Out:
# plot without title

# %%
ggplot(data=ages,
  aes(x=actor, fill=Genre)) +
  geom_bar(position="dodge")
# Out:
# plot without title

# %%
ggplot(data=ages,
  aes(x=actor, fill=Genre)) +
  geom_bar(position="fill")
# Out:
# plot without title

# %%
library(dplyr)

avg_age <- ages %>% 
  group_by(actor) %>%
  mutate(age_diff = actor_age-actress_age) %>% 
  summarize(average_age_diff = mean(age_diff))

# %%
ggplot(avg_age, aes(x=actor, y=average_age_diff, fill=actor)) + 
  geom_bar(stat="identity") +
  theme(legend.position="none") + # This removes the legend
  scale_fill_manual(values=c("aquamarine", "darkorchid", "deepskyblue2", "lemonchiffon2", "orange", "peachpuff3", "tomato"))
# Out:
# plot without title

# %%
ggplot(avg_age, aes(x=actor, y=average_age_diff, fill=actor)) + 
  geom_bar(stat="identity") +
  theme(legend.position="none") + 
  scale_fill_brewer()
# Out:
# plot without title

# %%
ggplot(avg_age, aes(x=actor, y=average_age_diff, fill=actor)) + 
  geom_bar(stat="identity") +
  theme(legend.position="none") + 
  scale_fill_brewer(palette="Pastel1")
# Out:
# plot without title

# %%
#You can annotate charts with annotate() and geom_hline() or geom_vline().


ggplot(ages, aes(x=actor_age, y=actress_age)) + 
  geom_point() +
  geom_hline(yintercept=50, color="red") +
  annotate("text", x=40, y=51, label="Random text for some reason", color="red")
# Out:
# plot without title

# %%
# If you don't have ggthemes installed yet, uncomment the line below and run it
#install.packages("ggthemes")

library(ggthemes)
ggplot(ages, aes(x=actor_age, y=actress_age, color=actor)) + 
  geom_point() +
  theme_economist() +
  scale_colour_economist()
# Out:
# plot without title

# %%
ggplot(ages, aes(x=actor_age, y=actress_age, color=actor)) + 
  geom_point() +
  theme_fivethirtyeight()
# Out:
# plot without title

# %%
ggplot(ages, aes(x=actor, y=actress_age)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data=ages, aes(x=actor_age)) +
  geom_histogram(binwidth=1)
# Out:
# plot without title

# %%
ggplot(data=ages, aes(x=actor_age)) +
  geom_histogram() + scale_x_log10()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(data=ages,
  aes(x=actress_age, fill=actor)) +
  geom_density(alpha=.3)
# Out:
# plot without title

# %%
ggplot(ages,
       aes(x=actress_age, y=Movie)) +
  geom_point()
# Out:
# plot without title

# %%
# Make them in order!!!

library(forcats)
ggplot(ages,
       aes(x=actress_age, y=fct_reorder(Movie, actress_age, desc=TRUE))) +
  geom_point()
# Out:
# plot without title

# %%
#Make a line to the points!

ggplot(ages,
       aes(x=actress_age, y=fct_reorder(Movie, actress_age, desc=TRUE))) +
  geom_segment(
       aes(x = 0,
           xend = actress_age,
           yend = fct_reorder(Movie, actress_age, desc=TRUE)),
           color = "gray50") +
           geom_point()
# Out:
# plot without title

# %%
ggplot(ages,
       aes(x=actress_age, y=fct_reorder(Movie, actress_age, desc=TRUE))) +
  geom_segment(
       aes(x = 0,
           y=fct_reorder(Movie, actress_age, desc=TRUE),
           xend = actress_age,
           yend = fct_reorder(Movie, actress_age, desc=TRUE)),
           color = "gray50") +
           geom_point() +
# NEW CODE BELOW
  labs(x="Actress age", y="Movie", 
       title = "Actress ages in movies",
       subtitle = "for R for Journalists class",
       caption = "Data from Vulture.com and IMDB") +
  theme_minimal()
# Out:
# plot without title

# %%
ggplot(ages,
       aes(x=actress_age, y=fct_reorder(Movie, actress_age, desc=TRUE))) +
  geom_segment(
       aes(x = 0,
           y=fct_reorder(Movie, actress_age, desc=TRUE),
           xend = actress_age,
           yend = fct_reorder(Movie, actress_age, desc=TRUE)),
           color = "gray50") +
           geom_point() +
  labs(x="Actress age", y="Movie", 
       title = "Actress ages in movies",
       subtitle = "for R for Journalists class",
       caption = "Data from Vulture.com and IMDB") +
  theme_minimal() +
  # NEW CODE BELOW
  geom_text(aes(label=actress_age), hjust=-.5) +
  theme(panel.border = element_blank(), 
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank(), 
        axis.line = element_blank(),
        axis.text.x = element_blank())
# Out:
# plot without title

# %%
ggsave("actress_ages.png")
# Out:
# Saving 7 x 7 in image

# %%
ggsave("actress_ages_adjusted.png", width=20, height=30, units="cm")

# %%
#png
#tex
#pdf
#jpeg
#tiff
#bmp
#svg

# %%
library(dplyr)

ages_reordered <- ages %>% 
  mutate(Movie=fct_reorder(Movie, desc(actor_age)))

ggplot(ages_reordered) +
  geom_segment(
       aes(x = actress_age,
           y = Movie,
           xend = actor_age,
           yend = Movie),
           color = "gray50") +
  geom_point(aes(x=actress_age, y=Movie), color="dark green") +
  geom_point(aes(x=actor_age, y=Movie), color="dark blue") +
  labs(x="", y="", 
       title = "Actor and actress ages in movies",
       subtitle = "for R for Journalists class",
       caption = "Data from Vulture.com and IMDB") +
  theme_minimal() +
  geom_text(aes(x=actress_age, y=Movie, label=actress_age), hjust=ifelse(ages$actress_age<ages$actor_age, 1.5, -.5)) +
  geom_text(aes(x=actor_age, y=Movie, label=actor_age), hjust=ifelse(ages$actress_age<ages$actor_age, -.5, 1.5)) +
  theme(panel.border = element_blank(), 
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank(), 
        axis.line = element_blank(),
        axis.text.x = element_blank())
# Out:
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:sos’:
#
#     matches
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# plot without title

# %%
ggplot(ages, aes(x=actor_age, y=actress_age)) + geom_point() +
  scale_x_continuous(breaks=seq(20,30,2), limits=c(20,30)) +
  scale_y_continuous(breaks=seq(20,40,4), limits=c(20,40))
# Out:
# Warning message:
# “Removed 67 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data=ages,
       aes(x=actor_age,
           y=actress_age,
           color=actor)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(data=ages,
       aes(x=actor_age,
           y=actress_age,
           color=actor,
           size=budget)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(data=ages) +
   geom_point(mapping=aes(x=actor_age, y=actress_age)) + 
   expand_limits(x = 0, y = 0) +
   geom_abline(intercept=0, col="light gray") +
   facet_grid(Genre~actor)
# Out:
# plot without title

# %%
ggplot(data=ages) +
   geom_point(mapping=aes(x=actor_age, y=actress_age, size=budget)) + 
   expand_limits(x = 0, y = 0) +
   geom_abline(intercept=0, col="light gray") +
   facet_grid(Genre~actor)
# Out:
# plot without title

# %%
ggplot(ages,
      aes(x=actor_age,
          y=actress_age)) +
      geom_point(aes(color=actor))
# Out:
# plot without title

# %%
# Let's make a copy of the  minus the actor variable so it can't be faceted
library(magrittr)
library(sos)
ages_copy <- ages %>% select(-actor)

ggplot(data=ages,
      aes(x=actor_age,
          y=actress_age,
          color=actor)) +
      geom_point(data=ages_copy, color="grey") +
      geom_point() +
      facet_wrap(~actor) +
      theme(legend.position="none") # This removes the legend
# Out:
# Loading required package: brew
#
# Attaching package: ‘sos’
#
# The following object is masked from ‘package:utils’:
#
#     ?
# Error in select(., -actor): could not find function "select"
# Traceback:
#
# 1. ages %>% select(-actor)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
